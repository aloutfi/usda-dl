# %%
import pandas as pd

# %%
df = pd.read_csv('data/usda.csv')

# %%
df
# Out:
#        Symbol Synonym Symbol  \
# 0        ABAB            NaN
# 1        ABAB          ABAM5
# 2        ABAB           ABJA
# 3        ABAB           ABLI
# 4      ABAB70            NaN
# ...       ...            ...
# 90904   ZYVIR         ZYVIR2
# 90905   ZYVIR         ZYVIV2
# 90906   ZYVIR           ZYVU
# 90907   ZYVIV            NaN
# 90908   ZYVIV          ZYVID
#
#                              Scientific Name with Author  \
# 0          Abutilon abutiloides (Jacq.) Garcke ex Hochr.
# 1                         Abutilon americanum (L.) Sweet
# 2                              Abutilon jacquinii G. Don
# 3                        Abutilon lignosum (Cav.) G. Don
# 4                  Abietinella abietina (Hedw.) Fleisch.
# ...                                                  ...
# 90904  Zygodon viridissimus (Dicks.) Brid. var. rufot...
# 90905  Zygodon viridissimus (Dicks.) Brid. var. vulga...
# 90906                    Zygodon vulgaris (Malta) Nyholm
# ...
