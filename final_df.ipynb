# %%
import pandas as pd

# %%
df = pd.read_csv('data/polity_cultivar_pomo_usda.csv')
df.head()
# Out:
#   pomological_Id                      artist_full_name fruit_scientific_name  \
# 0    POM00006406  Passmore, Deborah Griscom, 1840-1911       citrus sinensis
# 1    POM00006407  Passmore, Deborah Griscom, 1840-1911       citrus sinensis
# 2    POM00006463  Newton, Amanda Almira, ca. 1860-1943       citrus sinensis
# 3    POM00006465  Newton, Amanda Almira, ca. 1860-1943       citrus sinensis
# 4    POM00006446        Schutt, Ellen Isham, 1873-1955       citrus sinensis
#
#   fruit_common_name                                  geographic origin  \
# 0           oranges  Duarte, Los Angeles County, California, United...
# 1           oranges  Riverside, Riverside County, California, Unite...
# 2           oranges    Honcut, Butte County, California, United States
# 3           oranges    Honcut, Butte County, California, United States
# 4           oranges                                                NaN
#
#                    physical description specimen  image_created_year  \
# 0  1 art original : col. ; 17 x 25 cm.     19473                 NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440              1908.0
# 2  1 art original : col. ; 17 x 25 cm.     70748              1914.0
# 3  1 art original : col. ; 17 x 25 cm.    70748a              1914.0
# 4  1 art original : col. ; 17 x 26 cm.     37438              1906.0
#
#   notes on original date created fruit_variety  \
# 0               NaN          NaN    Navelencia
# 1               NaN         1908    Navelencia
# 2               NaN   1914-03-13           New
# 3      Peter Bisset   1914-03-16           New
# 4               NaN   1906-11-19       No. 779
#
#                                             nal note cultivar_name  \
# 0                                                NaN        citrus
# 1                                                NaN        citrus
# 2                                                NaN        citrus
# 3                                                NaN        citrus
# 4  Watercolor includes mock up for the Yearbook o...        citrus
#
#    is_usda_recognized                                  geographic_origin  \
# 0                True  Duarte, Los Angeles County, California, United...
# 1                True  Riverside, Riverside County, California, Unite...
# 2                True    Honcut, Butte County, California, United States
# 3                True    Honcut, Butte County, California, United States
# 4                True                                                NaN
#
#   common_name  is_originpolity_largest_producer
# 0     oranges                             False
# 1     oranges                             False
# 2     oranges                             False
# 3     oranges                             False
# 4     oranges                             False

# %%
def afn(_afn):
    _afn = _afn.artist_full_name
    if isinstance(_afn, str):
        _afn = _afn.split(',')
        _afn = [x.strip() for x in _afn]
        _afn = _afn[0:2]
        _afn = ''.join(_afn)
    return _afn
df['artist_full_name'] = df.apply(lambda x: afn(x), axis=1)

# %%
df.head()
# Out:
#   pomological_Id          artist_full_name fruit_scientific_name  \
# 0    POM00006406  Passmore Deborah Griscom       citrus sinensis
# 1    POM00006407  Passmore Deborah Griscom       citrus sinensis
# 2    POM00006463      Newton Amanda Almira       citrus sinensis
# 3    POM00006465      Newton Amanda Almira       citrus sinensis
# 4    POM00006446        Schutt Ellen Isham       citrus sinensis
#
#   fruit_common_name                                  geographic origin  \
# 0           oranges  Duarte, Los Angeles County, California, United...
# 1           oranges  Riverside, Riverside County, California, Unite...
# 2           oranges    Honcut, Butte County, California, United States
# 3           oranges    Honcut, Butte County, California, United States
# 4           oranges                                                NaN
#
#                    physical description specimen  image_created_year  \
# 0  1 art original : col. ; 17 x 25 cm.     19473                 NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440              1908.0
# 2  1 art original : col. ; 17 x 25 cm.     70748              1914.0
# 3  1 art original : col. ; 17 x 25 cm.    70748a              1914.0
# 4  1 art original : col. ; 17 x 26 cm.     37438              1906.0
#
#   notes on original date created fruit_variety  \
# 0               NaN          NaN    Navelencia
# 1               NaN         1908    Navelencia
# 2               NaN   1914-03-13           New
# 3      Peter Bisset   1914-03-16           New
# 4               NaN   1906-11-19       No. 779
#
#                                             nal note cultivar_name  \
# 0                                                NaN        citrus
# 1                                                NaN        citrus
# 2                                                NaN        citrus
# 3                                                NaN        citrus
# 4  Watercolor includes mock up for the Yearbook o...        citrus
#
#    is_usda_recognized                                  geographic_origin  \
# 0                True  Duarte, Los Angeles County, California, United...
# 1                True  Riverside, Riverside County, California, Unite...
# 2                True    Honcut, Butte County, California, United States
# 3                True    Honcut, Butte County, California, United States
# 4                True                                                NaN
#
#   common_name  is_originpolity_largest_producer fruit_origin_country
# 0     oranges                             False        United States
# 1     oranges                             False        United States
# 2     oranges                             False        United States
# 3     oranges                             False        United States
# 4     oranges                             False                  NaN

# %%
def foc(_x):
    _x = _x['geographic_origin']
    if isinstance(_x, str):
        _x = _x.split(',')[-1]
        _x = _x.strip()
    return _x
df['fruit_origin_country'] = df.apply(lambda x: foc(x), axis=1)
df.head()
# Out:
#   pomological_Id          artist_full_name fruit_scientific_name  \
# 0    POM00006406  Passmore Deborah Griscom       citrus sinensis
# 1    POM00006407  Passmore Deborah Griscom       citrus sinensis
# 2    POM00006463      Newton Amanda Almira       citrus sinensis
# 3    POM00006465      Newton Amanda Almira       citrus sinensis
# 4    POM00006446        Schutt Ellen Isham       citrus sinensis
#
#   fruit_common_name                                  geographic origin  \
# 0           oranges  Duarte, Los Angeles County, California, United...
# 1           oranges  Riverside, Riverside County, California, Unite...
# 2           oranges    Honcut, Butte County, California, United States
# 3           oranges    Honcut, Butte County, California, United States
# 4           oranges                                                NaN
#
#                    physical description specimen  image_created_year  \
# 0  1 art original : col. ; 17 x 25 cm.     19473                 NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440              1908.0
# 2  1 art original : col. ; 17 x 25 cm.     70748              1914.0
# 3  1 art original : col. ; 17 x 25 cm.    70748a              1914.0
# 4  1 art original : col. ; 17 x 26 cm.     37438              1906.0
#
#   notes on original date created fruit_variety  \
# 0               NaN          NaN    Navelencia
# 1               NaN         1908    Navelencia
# 2               NaN   1914-03-13           New
# 3      Peter Bisset   1914-03-16           New
# 4               NaN   1906-11-19       No. 779
#
#                                             nal note cultivar_name  \
# 0                                                NaN        citrus
# 1                                                NaN        citrus
# 2                                                NaN        citrus
# 3                                                NaN        citrus
# 4  Watercolor includes mock up for the Yearbook o...        citrus
#
#    is_usda_recognized                                  geographic_origin  \
# 0                True  Duarte, Los Angeles County, California, United...
# 1                True  Riverside, Riverside County, California, Unite...
# 2                True    Honcut, Butte County, California, United States
# 3                True    Honcut, Butte County, California, United States
# 4                True                                                NaN
#
#   common_name  is_originpolity_largest_producer fruit_origin_country
# 0     oranges                             False        United States
# 1     oranges                             False        United States
# 2     oranges                             False        United States
# 3     oranges                             False        United States
# 4     oranges                             False                  NaN

# %%
from collections import Counter
Counter(list(df['fruit_origin_country']))

# %%
def fop(_x):
    _x = _x['geographic_origin']
    if isinstance(_x, str):
        try:
            _x = _x.split(',')[-2]
        except:
            _x = None
    return _x
df['fruit_origin_polity'] = df.apply(lambda x: fop(x), axis=1)
df.head()
# Out:
#   pomological_Id          artist_full_name fruit_scientific_name  \
# 0    POM00006406  Passmore Deborah Griscom       citrus sinensis
# 1    POM00006407  Passmore Deborah Griscom       citrus sinensis
# 2    POM00006463      Newton Amanda Almira       citrus sinensis
# 3    POM00006465      Newton Amanda Almira       citrus sinensis
# 4    POM00006446        Schutt Ellen Isham       citrus sinensis
#
#   fruit_common_name                                  geographic origin  \
# 0           oranges  Duarte, Los Angeles County, California, United...
# 1           oranges  Riverside, Riverside County, California, Unite...
# 2           oranges    Honcut, Butte County, California, United States
# 3           oranges    Honcut, Butte County, California, United States
# 4           oranges                                                NaN
#
#                    physical description specimen  image_created_year  \
# 0  1 art original : col. ; 17 x 25 cm.     19473                 NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440              1908.0
# 2  1 art original : col. ; 17 x 25 cm.     70748              1914.0
# 3  1 art original : col. ; 17 x 25 cm.    70748a              1914.0
# 4  1 art original : col. ; 17 x 26 cm.     37438              1906.0
#
#   notes on original date created  ...  \
# 0               NaN          NaN  ...
# 1               NaN         1908  ...
# 2               NaN   1914-03-13  ...
# 3      Peter Bisset   1914-03-16  ...
# 4               NaN   1906-11-19  ...
#
#                                             nal note cultivar_name  \
# 0                                                NaN        citrus
# 1                                                NaN        citrus
# 2                                                NaN        citrus
# 3                                                NaN        citrus
# 4  Watercolor includes mock up for the Yearbook o...        citrus
#
#   is_usda_recognized                                  geographic_origin  \
# 0               True  Duarte, Los Angeles County, California, United...
# 1               True  Riverside, Riverside County, California, Unite...
# 2               True    Honcut, Butte County, California, United States
# 3               True    Honcut, Butte County, California, United States
# 4               True                                                NaN
#
#   common_name is_originpolity_largest_producer  fruit_origin_country  \
# 0     oranges                            False         United States
# 1     oranges                            False         United States
# 2     oranges                            False         United States
# 3     oranges                            False         United States
# 4     oranges                            False                   NaN
#
#   fruit_origin_politiy    image_url fruit_origin_polity
# 0           California  POM00006406          California
# 1           California  POM00006407          California
# 2           California  POM00006463          California
# 3           California  POM00006465          California
# 4                  NaN  POM00006446                 NaN
#
# [5 rows x 21 columns]

# %%
def iurl(_x):
    _x = _x['pomological_Id']
    return _x
df['image_url'] = df.apply(lambda x: iurl(x), axis=1)
df.head()
# Out:
#   pomological_Id          artist_full_name fruit_scientific_name  \
# 0    POM00006406  Passmore Deborah Griscom       citrus sinensis
# 1    POM00006407  Passmore Deborah Griscom       citrus sinensis
# 2    POM00006463      Newton Amanda Almira       citrus sinensis
# 3    POM00006465      Newton Amanda Almira       citrus sinensis
# 4    POM00006446        Schutt Ellen Isham       citrus sinensis
#
#   fruit_common_name                                  geographic origin  \
# 0           oranges  Duarte, Los Angeles County, California, United...
# 1           oranges  Riverside, Riverside County, California, Unite...
# 2           oranges    Honcut, Butte County, California, United States
# 3           oranges    Honcut, Butte County, California, United States
# 4           oranges                                                NaN
#
#                    physical description specimen  image_created_year  \
# 0  1 art original : col. ; 17 x 25 cm.     19473                 NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440              1908.0
# 2  1 art original : col. ; 17 x 25 cm.     70748              1914.0
# 3  1 art original : col. ; 17 x 25 cm.    70748a              1914.0
# 4  1 art original : col. ; 17 x 26 cm.     37438              1906.0
#
#   notes on original date created fruit_variety  \
# 0               NaN          NaN    Navelencia
# 1               NaN         1908    Navelencia
# 2               NaN   1914-03-13           New
# 3      Peter Bisset   1914-03-16           New
# 4               NaN   1906-11-19       No. 779
#
#                                             nal note cultivar_name  \
# 0                                                NaN        citrus
# 1                                                NaN        citrus
# 2                                                NaN        citrus
# 3                                                NaN        citrus
# 4  Watercolor includes mock up for the Yearbook o...        citrus
#
#    is_usda_recognized                                  geographic_origin  \
# 0                True  Duarte, Los Angeles County, California, United...
# 1                True  Riverside, Riverside County, California, Unite...
# 2                True    Honcut, Butte County, California, United States
# 3                True    Honcut, Butte County, California, United States
# 4                True                                                NaN
#
#   common_name  is_originpolity_largest_producer fruit_origin_country  \
# 0     oranges                             False        United States
# 1     oranges                             False        United States
# 2     oranges                             False        United States
# 3     oranges                             False        United States
# 4     oranges                             False                  NaN
#
#   fruit_origin_politiy    image_url
# 0           California  POM00006406
# 1           California  POM00006407
# 2           California  POM00006463
# 3           California  POM00006465
# 4                  NaN  POM00006446

# %%
df['is_usda_recognized_plant_family']=df['is_usda_recognized']
final = ['artist_full_name', 'cultivar_name', 'fruit_common_name', 'fruit_origin_country',
        'fruit_origin_polity', 'fruit_scientific_name', 'fruit_variety', 'image_created_year',
        'image_url', 'is_originpolity_largest_producer', 'is_usda_recognized_plant_family',
        'pomological_Id']
final_df = df[final]
final_df.index.name = '_index'

# %%
final_df.to_csv('data/final.csv', index=False)
