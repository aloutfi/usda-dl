# %%
import pandas as pd

# %%
cultivar_mappings={
    'apple':['apples', 'star apple', 'custard apple', 'sweetsops', 'pawpaws', 'crab apple', 'New Zealand nightshade', 'tree tomato', 'eggplants','mammee apple', 'white sapote', 'star apple'],
    'apricot':['peaches', 'Japenese apricot', 'bael', 'dates', 'glossy privet'],
    'berry':['persommons', 'strawberries', 'blackthorn','pomegranets', 'avocados', 'Chinese hawthorn', 
             'hawthorn', 'blueberries', 'American cranberry', 'goosberries', 'roselle','figs', 'mulberries', 
             'blackberries', 'red raspberries', 'brambles', 'purple raspberries','black raspberries', 'baobab', 'cloudberry', 
             'wineberry', 'raspberries' ],
    'cherry':['cherries', 'chokecherry', 'passfloria', 'Surinam cherry'],
    'citrus':['grapefruits', 'oranges','mandarins', 'tangerines', 'tangelos', 'satsumas', 'citrus fruits', 'citron', 
              'tangors', 'limes', 'lemons','tabog','limeberry',  'pumelos', 'nectarines', 'kumquats', 
              'Ogeechee tupelo', 'citranges', 'orangequat'],
    'grape': ['wampee', 'grapes','olives'],
    'nuts':['peanuts', 'hazelnuts', 'red mombins', 'tropical almond', 'walnuts', 'nutmeg', 'hickory', 'pekea nut', 
            'chestnuts', "St John's bread", 'cashew nuts', 'Italian stone pine', 'Japanese walnut', 'black walnut', 'English walnut', 
            'Eastern red cedar', 'Macadamia', 'pedans'],
    'peach':['loquats'],
    'pear':['prickly pear', 'chayote', 'Asian pear', 'Callery pear', 'Eastern shadbush'],
    'melon': ['watermelons', 'melons'],
    'quince': ['cherimoya', 'quinces'],
    'plum and prune':['plums', 'Japanese plum', 'apricot plum', 'Kaffir plum', 'cherry plum', 'Chickasaw plum', 'natal plum'],
    'tropical fruit': ['pineapples', 'guavas', 'Indian tamarind', 'mangoes', 'sapodillas', 'mangosteens', 
                       'doum palm', 'bananas', 'Acca', 'kiwifruit', 'yellow sapote', 'canistel', 'oak leaved papaya', 'papayas']
}

# %% [markdown]
# # Inverting cultivar mappings will improve performance

# %%
def invert_dict(d): 
    # Assumes no duplicate membership of common name to cultivar
    inverse = dict() 
    for key in d: 
        # Go through the list that is saved in the dict:
        for item in d[key]:
            # Check if in the inverted dict the key exists
            if item not in inverse: 
                # Add item to inverse. 
                inverse[item] = key 
    return inverse
inverted_cultivar_mappings = invert_dict(cultivar_mappings)
inverted_cultivar_mappings
# Out:
# {'apples': 'apple',
#  'star apple': 'apple',
#  'custard apple': 'apple',
#  'sweetsops': 'apple',
#  'pawpaws': 'apple',
#  'crab apple': 'apple',
#  'New Zealand nightshade': 'apple',
#  'tree tomato': 'apple',
#  'eggplants': 'apple',
#  'mammee apple': 'apple',
#  'white sapote': 'apple',
#  'peaches': 'apricot',
#  'Japenese apricot': 'apricot',
#  'bael': 'apricot',
#  'dates': 'apricot',
#  'glossy privet': 'apricot',
#  'persommons': 'berry',
#  'strawberries': 'berry',
#  'blackthorn': 'berry',
#  'pomegranets': 'berry',
#  'avocados': 'berry',
#  'Chinese hawthorn': 'berry',
#  'hawthorn': 'berry',
#  'blueberries': 'berry',
#  'American cranberry': 'berry',
#  'goosberries': 'berry',
#  'roselle': 'berry',
#  'figs': 'berry',
#  'mulberries': 'berry',
#  'blackberries': 'berry',
#  'red raspberries': 'berry',
#  'brambles': 'berry',
#  'purple raspberries': 'berry',
#  'black raspberries': 'berry',
#  'baobab': 'berry',
#  'cloudberry': 'berry',
#  'wineberry': 'berry',
#  'raspberries': 'berry',
#  'cherries': 'cherry',
#  'chokecherry': 'cherry',
#  'passfloria': 'cherry',
#  'Surinam cherry': 'cherry',
#  'grapefruits': 'citrus',
#  'oranges': 'citrus',
#  'mandarins': 'citrus',
#  'tangerines': 'citrus',
#  'tangelos': 'citrus',
#  'satsumas': 'citrus',
#  'citrus fruits': 'citrus',
#  'citron': 'citrus',
#  'tangors': 'citrus',
#  'limes': 'citrus',
#  'lemons': 'citrus',
#  'tabog': 'citrus',
#  'limeberry': 'citrus',
#  'pumelos': 'citrus',
#  'nectarines': 'citrus',
#  'kumquats': 'citrus',
#  'Ogeechee tupelo': 'citrus',
#  'citranges': 'citrus',
#  'orangequat': 'citrus',
#  'wampee': 'grape',
#  'grapes': 'grape',
#  'olives': 'grape',
#  'peanuts': 'nuts',
#  'hazelnuts': 'nuts',
#  'red mombins': 'nuts',
#  'tropical almond': 'nuts',
#  'walnuts': 'nuts',
#  'nutmeg': 'nuts',
#  'hickory': 'nuts',
#  'pekea nut': 'nuts',
#  'chestnuts': 'nuts',
#  "St John's bread": 'nuts',
#  'cashew nuts': 'nuts',
#  'Italian stone pine': 'nuts',
#  'Japanese walnut': 'nuts',
#  'black walnut': 'nuts',
#  'English walnut': 'nuts',
#  'Eastern red cedar': 'nuts',
#  'Macadamia': 'nuts',
#  'pedans': 'nuts',
#  'loquats': 'peach',
#  'prickly pear': 'pear',
#  'chayote': 'pear',
#  'Asian pear': 'pear',
#  'Callery pear': 'pear',
#  'Eastern shadbush': 'pear',
#  'watermelons': 'melon',
#  'melons': 'melon',
#  'cherimoya': 'quince',
#  'quinces': 'quince',
#  'plums': 'plum and prune',
#  'Japanese plum': 'plum and prune',
#  'apricot plum': 'plum and prune',
#  'Kaffir plum': 'plum and prune',
#  'cherry plum': 'plum and prune',
#  'Chickasaw plum': 'plum and prune',
#  'natal plum': 'plum and prune',
#  'pineapples': 'tropical fruit',
#  'guavas': 'tropical fruit',
#  'Indian tamarind': 'tropical fruit',
#  'mangoes': 'tropical fruit',
#  'sapodillas': 'tropical fruit',
#  'mangosteens': 'tropical fruit',
#  'doum palm': 'tropical fruit',
#  'bananas': 'tropical fruit',
#  'Acca': 'tropical fruit',
#  'kiwifruit': 'tropical fruit',
#  'yellow sapote': 'tropical fruit',
#  'canistel': 'tropical fruit',
#  'oak leaved papaya': 'tropical fruit',
#  'papayas': 'tropical fruit'}

# %%
df = pd.read_csv('data/usda_pomological.csv')
df.head()
# Out:
#          pomid                                artist  scientific name  \
# 0  POM00006406  Passmore, Deborah Griscom, 1840-1911  Citrus sinensis
# 1  POM00006407  Passmore, Deborah Griscom, 1840-1911  Citrus sinensis
# 2  POM00006463  Newton, Amanda Almira, ca. 1860-1943  Citrus sinensis
# 3  POM00006465  Newton, Amanda Almira, ca. 1860-1943  Citrus sinensis
# 4  POM00006446        Schutt, Ellen Isham, 1873-1955  Citrus sinensis
#
#   common name                                  geographic origin  \
# 0     oranges  Duarte, Los Angeles County, California, United...
# 1     oranges  Riverside, Riverside County, California, Unite...
# 2     oranges    Honcut, Butte County, California, United States
# 3     oranges    Honcut, Butte County, California, United States
# 4     oranges                                                NaN
#
#                    physical description specimen    year notes on original  \
# 0  1 art original : col. ; 17 x 25 cm.     19473     NaN               NaN
# 1  1 art original : col. ; 17 x 25 cm.     40440  1908.0               NaN
# 2  1 art original : col. ; 17 x 25 cm.     70748  1914.0               NaN
# 3  1 art original : col. ; 17 x 25 cm.    70748a  1914.0      Peter Bisset
# 4  1 art original : col. ; 17 x 26 cm.     37438  1906.0               NaN
#
#   date created     variety                                           nal note
# 0          NaN  Navelencia                                                NaN
# 1         1908  Navelencia                                                NaN
# 2   1914-03-13         New                                                NaN
# 3   1914-03-16         New                                                NaN
# 4   1906-11-19     No. 779  Watercolor includes mock up for the Yearbook o...

# %% [markdown]
# # Create a column called cultivar with the cultivar name mapped from common name

# %%
df[['cultivar']] = df['common name'].map(invert_dict(cultivar_mappings))
df
# Out:
#             pomid                                artist  scientific name  \
# 0     POM00006406  Passmore, Deborah Griscom, 1840-1911  Citrus sinensis
# 1     POM00006407  Passmore, Deborah Griscom, 1840-1911  Citrus sinensis
# 2     POM00006463  Newton, Amanda Almira, ca. 1860-1943  Citrus sinensis
# 3     POM00006465  Newton, Amanda Almira, ca. 1860-1943  Citrus sinensis
# 4     POM00006446        Schutt, Ellen Isham, 1873-1955  Citrus sinensis
# ...           ...                                   ...              ...
# 7579  POM00001050  Newton, Amanda Almira, ca. 1860-1943  Malus domestica
# 7580  POM00001051  Passmore, Deborah Griscom, 1840-1911  Malus domestica
# 7581  POM00001052                        Heiges, Bertha  Malus domestica
# 7582  POM00001053     Arnold, Mary Daisy, ca. 1873-1955  Malus domestica
# 7583  POM00001054     Arnold, Mary Daisy, ca. 1873-1955  Malus domestica
#
#      common name                                  geographic origin  \
# 0        oranges  Duarte, Los Angeles County, California, United...
# 1        oranges  Riverside, Riverside County, California, Unite...
# 2        oranges    Honcut, Butte County, California, United States
# 3        oranges    Honcut, Butte County, California, United States
# 4        oranges                                                NaN
# ...          ...                                                ...
# 7579      apples  Storm Lake, Buena Vista County, Iowa, United S...
# 7580      apples  Rosslyn, Arlington County, Virginia, United St...
# 7581      apples     Wilna, Harford County, Maryland, United States
# 7582      apples  Rosslyn, Arlington County, Virginia, United St...
# 7583      apples  Beltsville, Prince Georges County, Maryland, U...
#
#                       physical description specimen    year  \
# 0     1 art original : col. ; 17 x 25 cm.     19473     NaN
# 1     1 art original : col. ; 17 x 25 cm.     40440  1908.0
# 2     1 art original : col. ; 17 x 25 cm.     70748  1914.0
# 3     1 art original : col. ; 17 x 25 cm.    70748a  1914.0
# 4     1 art original : col. ; 17 x 26 cm.     37438  1906.0
# ...                                    ...      ...     ...
# 7579  1 art original : col. ; 16 x 25 cm.     40064  1908.0
# 7580  1 art original : col. ; 17 x 25 cm.    109640  1928.0
# 7581  1 art original : col. ; 17 x 25 cm.     33232  1905.0
# 7582  1 art original : col. ; 17 x 26 cm.    105989  1925.0
# 7583  1 art original : col. ; 17 x 25 cm.    102407  1939.0
#
#                notes on original date created      variety  \
# 0                            NaN          NaN   Navelencia
# 1                            NaN         1908   Navelencia
# 2                            NaN   1914-03-13          New
# 3                   Peter Bisset   1914-03-16          New
# 4                            NaN   1906-11-19      No. 779
# ...                          ...          ...          ...
# 7579                         NaN   1908-04-01       Anisim
# 7580                         NaN   1928-03-08      Annette
# 7581                         NaN   1905-01-25  Annie Frank
# 7582  Section F, Row 1-2, Tree 3   1925-01-21      Annurco
# 7583                         NaN   1939-09-09      Annurco
#
#                                                nal note cultivar
# 0                                                   NaN   citrus
# 1                                                   NaN   citrus
# 2                                                   NaN   citrus
# 3                                                   NaN   citrus
# 4     Watercolor includes mock up for the Yearbook o...   citrus
# ...                                                 ...      ...
# 7579                                                NaN    apple
# 7580                                                NaN    apple
# 7581                                                NaN    apple
# 7582                                                NaN    apple
# 7583                                                NaN    apple
#
# [7584 rows x 13 columns]

# %%
df.to_csv('data/cultivar-pomo.csv', index=False)
